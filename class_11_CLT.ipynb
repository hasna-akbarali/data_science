# %% [markdown]
# ### Central Limit Theoram

# %%
df = pd.read_csv('C:\\Users\\DELL\\Downloads\\car_performance.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   origin        392 non-null    object
#  1   cylinders     392 non-null    int64
#  2   model_year    392 non-null    int64
#  3   mpg_level     392 non-null    object
#  4   car_company   392 non-null    object
#  5   mpg           392 non-null    float64
#  6   displacement  392 non-null    float64
#  7   horsepower    392 non-null    float64
#  8   weight        392 non-null    int64
#  9   acceleration  392 non-null    float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 30.8+ KB

# %%
power = df['horsepower']

# %%
sns.histplot(power,kde=True)
# Out:
# <Axes: xlabel='horsepower', ylabel='Count'>

# %%
print('mean:',power.mean(),'std:',power.std())
# Out:
# mean: 104.46938775510205 std: 38.49115993282855

# %%
sample1=power.sample(n=40)
print('mean:',sample1.mean(),'std:',sample1.std())
# Out:
# mean: 99.05 std: 36.43325474456064

# %%
sample1=power.sample(n=60)
print('mean:',sample1.mean(),'std:',sample1.std())
# Out:
# mean: 104.15 std: 41.01790638328337

# %%
sample1=power.sample(n=100)
print('mean:',sample1.mean(),'std:',sample1.std())
# Out:
# mean: 102.88 std: 37.02886670824492

# %%
sample_mean31=[]
for i in range(100):
    sample_mean31.append(power.sample(5).mean())
sns.histplot(sample_mean31,kde=True,discrete=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sample_mean41=[]
for i in range(100):
    sample_mean41.append(power.sample(11).mean())
sns.histplot(sample_mean41,kde=True,discrete=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sample_mean21=[]
for i in range(100):
    sample_mean41.append(power.sample(31).mean())
sns.histplot(sample_mean41,kde=True,discrete=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sample_mean21=[]
for i in range(100):
    sample_mean41.append(power.sample(51).mean())
sns.histplot(sample_mean41,kde=True,discrete=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sample_mean21=[]
for i in range(100):
    sample_mean41.append(power.sample(71).mean())
sns.histplot(sample_mean41,kde=True,discrete=True)
# Out:
# <Axes: ylabel='Count'>
